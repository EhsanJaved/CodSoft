# %%
import pandas as pd
df = pd.read_csv("IRIS_FLOWER-CLASSIFICATION.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df['species'].value_counts()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# I want to see what are the other columns are ture of Iris-setosa
#
# I want to see what are the other columns are ture of Iris-versicolor
#
# I want to see what are the other columns are ture of Iris-virginica

# %%
setosa_samples = df[df['species'] == 'Iris-setosa']
versicolor_samples = df[df['species'] == 'Iris-versicolor']
virginica_samples = df[df['species'] == 'Iris-virginica']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(5,3))
sns.countplot(data=df , x='species')
plt.title('setosa_samples')
plt.show()

# %%
setosa_data = df[df['species'] == 'Iris-setosa']

# Create scatter plots
plt.figure(figsize=(7, 3))

# Sepal Length vs. Sepal Width
plt.subplot(1, 2, 1)
plt.scatter(setosa_data['sepal_length'], setosa_data['sepal_width'], c='blue', label='Iris-setosa')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.legend()

# Petal Length vs. Petal Width
plt.subplot(1, 2, 2)
plt.scatter(setosa_data['petal_length'], setosa_data['petal_width'], c='red', label='Iris-setosa')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.legend()

plt.tight_layout()
plt.show()

# %%
setosa_data = df[df['species'] == 'Iris-setosa']

# Calculate the average values for each feature
average_sepal_length = setosa_data['sepal_length'].mean()
average_sepal_width = setosa_data['sepal_width'].mean()
average_petal_length = setosa_data['petal_length'].mean()
average_petal_width = setosa_data['petal_width'].mean()

# Create a bar chart
plt.figure(figsize=(8, 6))
features = ['Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width']
values = [average_sepal_length, average_sepal_width, average_petal_length, average_petal_width]

plt.bar(features, values, color='blue')
plt.xlabel('Features')
plt.ylabel('Average Value (cm)')
plt.title('Average Feature Values for Iris-setosa')
plt.show()

# %%
setosa_data = df[df['species'] == 'Iris-virginica']

# Calculate the average values for each feature
average_sepal_length = setosa_data['sepal_length'].mean()
average_sepal_width = setosa_data['sepal_width'].mean()
average_petal_length = setosa_data['petal_length'].mean()
average_petal_width = setosa_data['petal_width'].mean()

# Create a bar chart
plt.figure(figsize=(8, 6))
features = ['Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width']
values = [average_sepal_length, average_sepal_width, average_petal_length, average_petal_width]

plt.bar(features, values, color='blue')
plt.xlabel('Features')
plt.ylabel('Average Value (cm)')
plt.title('Average Feature Values for Iris-virginica')
plt.show()

# %%
setosa_data = df[df['species'] == 'Iris-versicolor']

# Calculate the average values for each feature
average_sepal_length = setosa_data['sepal_length'].mean()
average_sepal_width = setosa_data['sepal_width'].mean()
average_petal_length = setosa_data['petal_length'].mean()
average_petal_width = setosa_data['petal_width'].mean()

# Create a bar chart
plt.figure(figsize=(8, 6))
features = ['Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width']
values = [average_sepal_length, average_sepal_width, average_petal_length, average_petal_width]

plt.bar(features, values, color='blue')
plt.xlabel('Features')
plt.ylabel('Average Value (cm)')
plt.title('Average Feature Values for Iris-versicolor')
plt.show()

# %%
df.isnull().value_counts()
# Out:
# sepal_length  sepal_width  petal_length  petal_width  species
# False         False        False         False        False      150
# Name: count, dtype: int64

# %%
df.value_counts()
# Out:
# sepal_length  sepal_width  petal_length  petal_width  species
# 4.9           3.1          1.5           0.1          Iris-setosa        3
# 5.8           2.7          5.1           1.9          Iris-virginica     2
#               4.0          1.2           0.2          Iris-setosa        1
# 5.9           3.0          4.2           1.5          Iris-versicolor    1
# 6.2           3.4          5.4           2.3          Iris-virginica     1
#                                                                         ..
# 5.5           2.3          4.0           1.3          Iris-versicolor    1
#               2.4          3.7           1.0          Iris-versicolor    1
#                            3.8           1.1          Iris-versicolor    1
#               2.5          4.0           1.3          Iris-versicolor    1
# 7.9           3.8          6.4           2.0          Iris-virginica     1
# Name: count, Length: 147, dtype: int64

# %%
from sklearn.model_selection import train_test_split

x = df[['sepal_length','sepal_width','petal_length','petal_width']]
y = df['species']

x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier()

clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import accuracy_score, classification_report

y_pred = clf.predict(x_test)


accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

report = classification_report(y_test, y_pred)
print(report)
# Out:
# Accuracy: 1.0
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       1.00      1.00      1.00         9
#  Iris-virginica       1.00      1.00      1.00        11
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30
